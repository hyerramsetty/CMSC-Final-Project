# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from numpy import *
import matplotlib.pyplot as plt
from sys import argv


Reads arguments from command line
if len(argv) == 3:
    ProvinceName = argv[1]
    Date = argv[2]





def GetProvincialData(unqid):
    """ Returns date which is specific to the province with the help of unique ID of the province
    Filters the rest of data
    """
    Province = [0] * len(covid[0])
    for i in range(len(covid)):
        if covid[i][0] == UniqueProvinceID[unqid]:
            Province = np.vstack([Province, covid[i]])
    Province = np.delete(Province, 0, 0)
    return Province


def GetTotalCasesList(Province):
    """Returns lists (Total Cases, Total tests, New cases, Total deaths) of province whith the help of argument Province which is passed to the function"""
    Dates = [""] * len(Province)
    TotalCases = [0] * len(Province)
    NumOfTested = [0] * len(Province)
    NumOfNewCasesPerDay = [0] * len(Province)
    TotalDeaths = [0] * len(Province)
    for i in range(len(Province)):
        Dates[i] = Province[i][3]
        TotalCases[i] = Province[i][7]
        NumOfTested[i] = Province[i][8]
        NumOfNewCasesPerDay[i] = Province[i][12]
        TotalDeaths[i] = Province[i][6]
    return TotalCases, Dates, NumOfTested, NumOfNewCasesPerDay, TotalDeaths


#CSV URL for the Covid data
CSV_URL = "https://health-infobase.canada.ca/src/data/covidLive/covid19.csv"

#Reading data from csv to variable data
data = pd.read_csv(CSV_URL)

#Copy data obtained from pandas to numpy array and assigned to a variable named covid
covid = np.array(data)

ProvinceID = [0]*len(covid)


#Getting province id column from data
for i in range(len(covid)):
    ProvinceID[i] = covid[i][0]
#Getting unique ids from all ids in the id column of data which is later used to refer each feature
UniqueProvinceID = list(dict.fromkeys(ProvinceID))

#Pulling Provincial specific data
Ontario = GetProvincialData(0)
BritishColumbia = GetProvincialData(1)
Canada = GetProvincialData(2)
Quebec = GetProvincialData(3)
Alberta = GetProvincialData(4)
Saskatchewan = GetProvincialData(5)
Manitoba = GetProvincialData(6)
NewBrunswick = GetProvincialData(7)
NewfoundlandAndLabrador = GetProvincialData(8)
NovaScotia = GetProvincialData(9)
PrinceEdwardIsland = GetProvincialData(10)
NorthwestTerritories = GetProvincialData(11)
Nunavut = GetProvincialData(12)
Yukon = GetProvincialData(13)
RepatriatedTravellers = GetProvincialData(14)


#Ontario Data
OntarioTotalCasesList, Dates1, OntarioTotalTested, OntarioNewCasesPerDay, OntarioTotalDeaths = GetTotalCasesList(Ontario)
OntarioTotalCasesList = np.pad(OntarioTotalCasesList, (len(OntarioTotalCasesList)-len(Dates1), 0), 'constant', constant_values=(0, 0))
OntarioTotalTested = np.pad(OntarioTotalTested, (len(OntarioTotalTested)-len(Dates1), 0), 'constant', constant_values=(0, 0))
OntarioNewCasesPerDay = np.pad(OntarioNewCasesPerDay, (len(OntarioNewCasesPerDay)-len(Dates1), 0), 'constant', constant_values=(0, 0))
OntarioTotalDeaths = np.pad(OntarioTotalDeaths, (len(OntarioTotalDeaths)-len(Dates1), 0), 'constant', constant_values=(0, 0))




#BritishColumbia Data
BritishColumbiaTotalCasesList, Dates, BritishColumbiaTotalTested, BritishColumbiaNewCasesPerDay, BritishColumbiaTotalDeaths = GetTotalCasesList(BritishColumbia)
BritishColumbiaTotalCasesList = np.pad(BritishColumbiaTotalCasesList, (len(OntarioTotalCasesList)-len(BritishColumbiaTotalCasesList), 0), 'constant', constant_values=(0, 0))
BritishColumbiaTotalTested = np.pad(BritishColumbiaTotalTested, (len(OntarioTotalCasesList)-len(BritishColumbiaTotalTested), 0), 'constant', constant_values=(0, 0))
BritishColumbiaNewCasesPerDay = np.pad(BritishColumbiaNewCasesPerDay, (len(OntarioTotalCasesList)-len(BritishColumbiaNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
BritishColumbiaTotalDeaths = np.pad(BritishColumbiaTotalDeaths, (len(OntarioTotalCasesList)-len(BritishColumbiaTotalDeaths), 0), 'constant', constant_values=(0, 0))



#Canada Data
CanadaTotalCasesList, Dates, CanadaTotalTested, CanadaNewCasesPerDay, CanadaTotalDeaths = GetTotalCasesList(Canada)
CanadaTotalCasesList = np.pad(CanadaTotalCasesList, (len(OntarioTotalCasesList)-len(CanadaTotalCasesList), 0), 'constant', constant_values=(0, 0))
CanadaTotalTested = np.pad(CanadaTotalTested, (len(OntarioTotalCasesList)-len(CanadaTotalTested), 0), 'constant', constant_values=(0, 0))
CanadaNewCasesPerDay = np.pad(CanadaNewCasesPerDay, (len(OntarioTotalCasesList)-len(CanadaNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
CanadaTotalDeaths = np.pad(CanadaTotalDeaths, (len(OntarioTotalCasesList)-len(CanadaTotalDeaths), 0), 'constant', constant_values=(0, 0))



#Quebec Data
QuebecTotalCasesList, Dates, QuebecTotalTested, QuebecNewCasesPerDay, QuebecTotalDeaths = GetTotalCasesList(Quebec)
QuebecTotalCasesList = np.pad(QuebecTotalCasesList, (len(OntarioTotalCasesList)-len(QuebecTotalCasesList), 0), 'constant', constant_values=(0, 0))
QuebecTotalTested = np.pad(QuebecTotalTested, (len(OntarioTotalCasesList)-len(QuebecTotalTested), 0), 'constant', constant_values=(0, 0))
QuebecNewCasesPerDay = np.pad(QuebecNewCasesPerDay, (len(OntarioTotalCasesList)-len(QuebecNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
QuebecTotalDeaths = np.pad(QuebecTotalDeaths, (len(OntarioTotalCasesList)-len(QuebecTotalDeaths), 0), 'constant', constant_values=(0, 0))



#Alberta Data
AlbertaTotalCasesList, Dates, AlbertaTotalTested, AlbertaNewCasesPerDay, AlbertaTotalDeaths = GetTotalCasesList(Alberta)
AlbertaTotalCasesList = np.pad(AlbertaTotalCasesList, (len(OntarioTotalCasesList)-len(AlbertaTotalCasesList), 0), 'constant', constant_values=(0, 0))
AlbertaTotalTested = np.pad(AlbertaTotalTested, (len(OntarioTotalCasesList)-len(AlbertaTotalTested), 0), 'constant', constant_values=(0, 0))
AlbertaNewCasesPerDay = np.pad(AlbertaNewCasesPerDay, (len(OntarioTotalCasesList)-len(AlbertaNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
AlbertaTotalDeaths = np.pad(AlbertaTotalDeaths, (len(OntarioTotalCasesList)-len(AlbertaTotalDeaths), 0), 'constant', constant_values=(0, 0))


#Saskatchewan Data
SaskatchewanTotalCasesList, Dates, SaskatchewanTotalTested, SaskatchewanNewCasesPerDay, SaskatchewanTotalDeaths = GetTotalCasesList(Saskatchewan)
SaskatchewanTotalCasesList = np.pad(SaskatchewanTotalCasesList, (len(OntarioTotalCasesList)-len(SaskatchewanTotalCasesList), 0), 'constant', constant_values=(0, 0))
SaskatchewanTotalTested = np.pad(SaskatchewanTotalTested, (len(OntarioTotalCasesList)-len(SaskatchewanTotalTested), 0), 'constant', constant_values=(0, 0))
SaskatchewanNewCasesPerDay = np.pad(SaskatchewanNewCasesPerDay, (len(OntarioTotalCasesList)-len(SaskatchewanNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
SaskatchewanTotalDeaths = np.pad(SaskatchewanTotalDeaths, (len(OntarioTotalCasesList)-len(SaskatchewanTotalDeaths), 0), 'constant', constant_values=(0, 0))



#Manitoba Data
ManitobaTotalCasesList, Dates, ManitobaTotalTested, ManitobaNewCasesPerDay, ManitobaTotalDeaths = GetTotalCasesList(Manitoba)
ManitobaTotalCasesList = np.pad(ManitobaTotalCasesList, (len(OntarioTotalCasesList)-len(ManitobaTotalCasesList), 0), 'constant', constant_values=(0, 0))
ManitobaTotalTested = np.pad(ManitobaTotalTested, (len(OntarioTotalCasesList)-len(ManitobaTotalTested), 0), 'constant', constant_values=(0, 0))
ManitobaNewCasesPerDay = np.pad(ManitobaNewCasesPerDay, (len(OntarioTotalCasesList)-len(ManitobaNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
ManitobaTotalDeaths = np.pad(ManitobaTotalDeaths, (len(OntarioTotalCasesList)-len(ManitobaTotalDeaths), 0), 'constant', constant_values=(0, 0))



#NewBrunswick Data
NewBrunswickTotalCasesList, Dates, NewBrunswickTotalTested, NewBrunswickNewCasesPerDay, NewBrunswickTotalDeaths = GetTotalCasesList(NewBrunswick)
NewBrunswickTotalCasesList = np.pad(NewBrunswickTotalCasesList, (len(OntarioTotalCasesList)-len(NewBrunswickTotalCasesList), 0), 'constant', constant_values=(0, 0))
NewBrunswickTotalTested = np.pad(NewBrunswickTotalTested, (len(OntarioTotalCasesList)-len(NewBrunswickTotalTested), 0), 'constant', constant_values=(0, 0))
NewBrunswickNewCasesPerDay = np.pad(NewBrunswickNewCasesPerDay, (len(OntarioTotalCasesList)-len(NewBrunswickNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
NewBrunswickTotalDeaths = np.pad(NewBrunswickTotalDeaths, (len(OntarioTotalCasesList)-len(NewBrunswickTotalDeaths), 0), 'constant', constant_values=(0, 0))
DayNumber = np.arange(len(Dates1))+1




#Newfoundland Data
NewfoundlandAndLabradorTotalCasesList, Dates, NewfoundlandAndLabradorTotalTested, NewfoundlandAndLabradorNewCasesPerDay, NewfoundlandAndLabradorTotalDeaths = GetTotalCasesList(NewfoundlandAndLabrador)
NewfoundlandAndLabradorTotalCasesList = np.pad(NewfoundlandAndLabradorTotalCasesList, (len(OntarioTotalCasesList)-len(NewfoundlandAndLabradorTotalCasesList), 0), 'constant', constant_values=(0, 0))
NewfoundlandAndLabradorTotalTested = np.pad(NewfoundlandAndLabradorTotalTested, (len(OntarioTotalCasesList)-len(NewfoundlandAndLabradorTotalTested), 0), 'constant', constant_values=(0, 0))
NewfoundlandAndLabradorNewCasesPerDay = np.pad(NewfoundlandAndLabradorNewCasesPerDay, (len(OntarioTotalCasesList)-len(NewfoundlandAndLabradorNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
NewfoundlandAndLabradorTotalDeaths = np.pad(NewfoundlandAndLabradorTotalDeaths, (len(OntarioTotalCasesList)-len(NewfoundlandAndLabradorTotalDeaths), 0), 'constant', constant_values=(0, 0))




#NovaScotia Data
NovaScotiaTotalCasesList, Dates, NovaScotiaTotalTested, NovaScotiaNewCasesPerDay, NovaScotiaTotalDeaths = GetTotalCasesList(NovaScotia)
NovaScotiaTotalCasesList = np.pad(NovaScotiaTotalCasesList, (len(OntarioTotalCasesList)-len(NovaScotiaTotalCasesList), 0), 'constant', constant_values=(0, 0))
NovaScotiaTotalTested = np.pad(NovaScotiaTotalTested, (len(OntarioTotalCasesList)-len(NovaScotiaTotalTested), 0), 'constant', constant_values=(0, 0))
NovaScotiaNewCasesPerDay = np.pad(NovaScotiaNewCasesPerDay, (len(OntarioTotalCasesList)-len(NovaScotiaNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
NovaScotiaTotalDeaths = np.pad(NovaScotiaTotalDeaths, (len(OntarioTotalCasesList)-len(NovaScotiaTotalDeaths), 0), 'constant', constant_values=(0, 0))




#PrinceEdward Data
PrinceEdwardIslandTotalCasesList, Dates, PrinceEdwardIslandTotalTested, PrinceEdwardIslandNewCasesPerDay, PrinceEdwardIslandTotalDeaths = GetTotalCasesList(PrinceEdwardIsland)
PrinceEdwardIslandTotalCasesList = np.pad(PrinceEdwardIslandTotalCasesList, (len(OntarioTotalCasesList)-len(PrinceEdwardIslandTotalCasesList), 0), 'constant', constant_values=(0, 0))
PrinceEdwardIslandTotalTested = np.pad(PrinceEdwardIslandTotalTested, (len(OntarioTotalCasesList)-len(PrinceEdwardIslandTotalTested), 0), 'constant', constant_values=(0, 0))
PrinceEdwardIslandNewCasesPerDay = np.pad(PrinceEdwardIslandNewCasesPerDay, (len(OntarioTotalCasesList)-len(PrinceEdwardIslandNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
PrinceEdwardIslandTotalDeaths = np.pad(PrinceEdwardIslandTotalDeaths, (len(OntarioTotalCasesList)-len(PrinceEdwardIslandTotalDeaths), 0), 'constant', constant_values=(0, 0))




#NorthwestTerritories Data
NorthwestTerritoriesTotalCasesList, Dates, NorthwestTerritoriesTotalTested, NorthwestTerritoriesNewCasesPerDay, NorthwestTerritoriesTotalDeaths = GetTotalCasesList(NorthwestTerritories)
NorthwestTerritoriesTotalCasesList = np.pad(NorthwestTerritoriesTotalCasesList, (len(OntarioTotalCasesList)-len(NorthwestTerritoriesTotalCasesList), 0), 'constant', constant_values=(0, 0))
NorthwestTerritoriesTotalTested = np.pad(NorthwestTerritoriesTotalTested, (len(OntarioTotalCasesList)-len(NorthwestTerritoriesTotalTested), 0), 'constant', constant_values=(0, 0))
NorthwestTerritoriesNewCasesPerDay = np.pad(NorthwestTerritoriesNewCasesPerDay, (len(OntarioTotalCasesList)-len(NorthwestTerritoriesNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
NorthwestTerritoriesTotalDeaths = np.pad(NorthwestTerritoriesTotalDeaths, (len(OntarioTotalCasesList)-len(NorthwestTerritoriesTotalDeaths), 0), 'constant', constant_values=(0, 0))




#Nunavut Data
NunavutTotalCasesList, Dates, NunavutTotalTested, NunavutNewCasesPerDay, NunavutTotalDeaths = GetTotalCasesList(Nunavut)
NunavutTotalCasesList = np.pad(NunavutTotalCasesList, (len(OntarioTotalCasesList)-len(NunavutTotalCasesList), 0), 'constant', constant_values=(0, 0))
NunavutTotalTested = np.pad(NunavutTotalTested, (len(OntarioTotalCasesList)-len(NunavutTotalTested), 0), 'constant', constant_values=(0, 0))
NunavutNewCasesPerDay = np.pad(NunavutNewCasesPerDay, (len(OntarioTotalCasesList)-len(NunavutNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
NunavutTotalDeaths = np.pad(NunavutTotalDeaths, (len(OntarioTotalCasesList)-len(NunavutTotalDeaths), 0), 'constant', constant_values=(0, 0))



#Yukon Data
YukonTotalCasesList, Dates, YukonTotalTested, YukonNewCasesPerDay, YukonTotalDeaths = GetTotalCasesList(Yukon)
YukonTotalCasesList = np.pad(YukonTotalCasesList, (len(OntarioTotalCasesList)-len(YukonTotalCasesList), 0), 'constant', constant_values=(0, 0))
YukonTotalTested = np.pad(YukonTotalTested, (len(OntarioTotalCasesList)-len(YukonTotalTested), 0), 'constant', constant_values=(0, 0))
YukonNewCasesPerDay = np.pad(YukonNewCasesPerDay, (len(OntarioTotalCasesList)-len(YukonNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
YukonTotalDeaths = np.pad(YukonTotalDeaths, (len(OntarioTotalCasesList)-len(YukonTotalDeaths), 0), 'constant', constant_values=(0, 0))



#RepatriatedTravellers Data
RepatriatedTravellersTotalCasesList, Dates, RepatriatedTravellersTotalTested, RepatriatedTravellersNewCasesPerDay, RepatriatedTravellersTotalDeaths = GetTotalCasesList(RepatriatedTravellers)
RepatriatedTravellersTotalCasesList = np.pad(RepatriatedTravellersTotalCasesList, (len(OntarioTotalCasesList)-len(RepatriatedTravellersTotalCasesList), 0), 'constant', constant_values=(0, 0))
RepatriatedTravellersTotalTested = np.pad(RepatriatedTravellersTotalTested, (len(OntarioTotalCasesList)-len(RepatriatedTravellersTotalTested), 0), 'constant', constant_values=(0, 0))
RepatriatedTravellersNewCasesPerDay = np.pad(RepatriatedTravellersNewCasesPerDay, (len(OntarioTotalCasesList)-len(RepatriatedTravellersNewCasesPerDay), 0), 'constant', constant_values=(0, 0))
RepatriatedTravellersTotalDeaths = np.pad(RepatriatedTravellersTotalDeaths, (len(OntarioTotalCasesList)-len(RepatriatedTravellersTotalDeaths), 0), 'constant', constant_values=(0, 0))




def DoubRat(Province):
    """ Makes use of Machine learning meathod(LinearRegression) to fit the current data and predict the new data"""
    #Replaced NaN values with zeros
    a = Province

    #Returns the index of the date from Dates list which is later used to refer to the corresponding value of (Total Cases list, Total Tests, Total new cases, Total Deaths)
    for i in range(len(Dates1)):
        if date == Dates1[i]:
            index = i

    where_are_NaNs = isnan(a)
    a[where_are_NaNs] = 0

    x = a.reshape((-1, 1))
    y = DayNumber
    model = LinearRegression().fit(x, y)
    #DoublingRate
    x = np.array([2 * a[index]]).reshape((-1, 1))
    y_pred = model.predict(x)
    return abs(y_pred[0] - len(DayNumber))


#Writing data to a file
f = open("DoublingRateData.txt", "w")
f.write('Predtions of Doublin retes' + '\n\n')
f.write('Predtion data for total cases to double in each province' + '\n')
f.write('Ontario ' + str(DoubRat(OntarioTotalCasesList)) +' days'+ '\n')
f.write('Britishcolumbia ' + str(DoubRat(BritishColumbiaTotalCasesList))+' days' + '\n')
f.write('Canada ' + str(DoubRat(CanadaTotalCasesList)) +' days'+ '\n')
f.write('Quebec ' + str(DoubRat(QuebecTotalCasesList)) +' days'+ '\n')
f.write('Alberta ' + str(DoubRat(AlbertaTotalCasesList)) +' days'+ '\n')
f.write('Manitoba ' + str(DoubRat(ManitobaTotalCasesList)) +' days'+ '\n')
f.write('Saskatchewan ' + str(DoubRat(SaskatchewanTotalCasesList)) +' days'+ '\n')
f.write('NewBrunswick ' + str(DoubRat(NewBrunswickTotalCasesList)) +' days'+ '\n')
f.write('Newfoundland ' + str(DoubRat(NewfoundlandAndLabradorTotalCasesList)) +' days'+ '\n')
f.write('NovaScotia ' + str(DoubRat(NovaScotiaTotalCasesList)) + ' days' + '\n')
f.write('PrinceEdwardIsland ' + str(DoubRat(PrinceEdwardIslandTotalCasesList)) + ' days' + '\n\n')

f.write('Predtion data for total tests to double in each province' + '\n')
f.write('Ontario ' + str(DoubRat(OntarioTotalTested)) +' days'+ '\n')
f.write('Britishcolumbia ' + str(DoubRat(BritishColumbiaTotalTested))+' days' + '\n')
f.write('Canada ' + str(DoubRat(CanadaTotalTested)) +' days'+ '\n')
f.write('Quebec ' + str(DoubRat(QuebecTotalTested)) +' days'+ '\n')
f.write('Alberta ' + str(DoubRat(AlbertaTotalTested)) +' days'+ '\n')
f.write('Manitoba ' + str(DoubRat(ManitobaTotalTested)) +' days'+ '\n')
f.write('Saskatchewan ' + str(DoubRat(SaskatchewanTotalTested)) +' days'+ '\n')
f.write('NewBrunswick ' + str(DoubRat(NewBrunswickTotalTested)) +' days'+ '\n')
f.write('Newfoundland ' + str(DoubRat(NewfoundlandAndLabradorTotalTested)) +' days'+ '\n')
f.write('NovaScotia ' + str(DoubRat(NovaScotiaTotalTested)) + ' days' + '\n')
f.write('PrinceEdwardIsland ' + str(DoubRat(PrinceEdwardIslandTotalTested)) + ' days' + '\n\n')


f.write('Predtion data for new cases to double in each province' + '\n')
f.write('Ontario ' + str(DoubRat(OntarioNewCasesPerDay)) +' days'+ '\n')
f.write('Britishcolumbia ' + str(DoubRat(BritishColumbiaNewCasesPerDay))+' days' + '\n')
f.write('Canada ' + str(DoubRat(CanadaNewCasesPerDay)) +' days'+ '\n')
f.write('Quebec ' + str(DoubRat(QuebecNewCasesPerDay)) +' days'+ '\n')
f.write('Alberta ' + str(DoubRat(AlbertaNewCasesPerDay)) +' days'+ '\n')
f.write('Manitoba ' + str(DoubRat(ManitobaNewCasesPerDay)) +' days'+ '\n')
f.write('Saskatchewan ' + str(DoubRat(SaskatchewanNewCasesPerDay)) +' days'+ '\n')
f.write('NewBrunswick ' + str(DoubRat(NewBrunswickNewCasesPerDay)) +' days'+ '\n')
f.write('Newfoundland ' + str(DoubRat(NewfoundlandAndLabradorNewCasesPerDay)) +' days'+ '\n')
f.write('NovaScotia ' + str(DoubRat(NovaScotiaNewCasesPerDay)) + ' days' + '\n')
f.write('PrinceEdwardIsland ' + str(DoubRat(PrinceEdwardIslandNewCasesPerDay)) + ' days' + '\n\n')

f.write('Predtion data for total deaths to double in each province' + '\n')
f.write('Ontario ' + str(DoubRat(OntarioTotalDeaths)) +' days'+ '\n')
f.write('Britishcolumbia ' + str(DoubRat(BritishColumbiaTotalDeaths))+' days' + '\n')
f.write('Canada ' + str(DoubRat(CanadaTotalDeaths)) +' days'+ '\n')
f.write('Quebec ' + str(DoubRat(QuebecTotalDeaths)) +' days'+ '\n')
f.write('Alberta ' + str(DoubRat(AlbertaTotalDeaths)) +' days'+ '\n')
f.write('Manitoba ' + str(DoubRat(ManitobaTotalDeaths)) +' days'+ '\n')
f.write('Saskatchewan ' + str(DoubRat(SaskatchewanTotalDeaths)) +' days'+ '\n')
f.write('NewBrunswick ' + str(DoubRat(NewBrunswickTotalDeaths)) +' days'+ '\n')
f.write('Newfoundland ' + str(DoubRat(NewfoundlandAndLabradorTotalDeaths)) +' days'+ '\n')
f.write('NovaScotia ' + str(DoubRat(NovaScotiaTotalDeaths)) + ' days' + '\n')
f.write('PrinceEdwardIsland ' + str(DoubRat(PrinceEdwardIslandTotalDeaths)) + ' days' + '\n\n')

f.close()

#Pulling data from DoubRate function by passing total tested list of each province as argument
Pr1 = DoubRat(OntarioTotalTested)
Pr2 = DoubRat(BritishColumbiaTotalTested)
Pr3 = DoubRat(CanadaTotalTested)
Pr4 = DoubRat(QuebecTotalTested)
Pr5 = DoubRat(AlbertaTotalTested)
Pr6 = DoubRat(ManitobaTotalTested)
Pr7 = DoubRat(SaskatchewanTotalTested)
Pr8 = DoubRat(NewBrunswickTotalTested)
Pr9 = DoubRat(NewfoundlandAndLabradorTotalTested)
Pr10 = DoubRat(NovaScotiaTotalTested)
Pr11 = DoubRat(PrinceEdwardIslandTotalTested)
Pr12 = DoubRat(NunavutTotalTested)
Pr13 = DoubRat(YukonTotalTested)
Pr14 = DoubRat(RepatriatedTravellersTotalTested)

#Plottting data for prediction of total tests
Results = ['Ontario', 'BritishColumbia', 'Canada', 'Quebec', 'Alberta', 'Manitoba', 'Saskatchewan', 'NewBrunswick', 'Newfoundland', 'NovaScotia', 'PrinceEdward', 'Nunavut', 'Yukon', 'Repatriated']
Days = [Pr1, Pr2, Pr3, Pr4, Pr5, Pr6, Pr7, Pr8, Pr9, Pr10, Pr11, Pr12, Pr13, Pr14]
plt.bar(Results, Days)
plt.xticks(Results, Results, rotation='vertical')
plt.ylabel('Doubling rate for Total tested ')
plt.title('Doubling rate plot')
plt.gcf().subplots_adjust(bottom=0.30)
plt.savefig('DoublingRateTotalTested.png')
plt.show()


#Pulling data from DoubRate function by passing total cases list of each province as argument
Pr1 = DoubRat(OntarioTotalCasesList)
Pr2 = DoubRat(BritishColumbiaTotalCasesList)
Pr3 = DoubRat(CanadaTotalCasesList)
Pr4 = DoubRat(QuebecTotalCasesList)
Pr5 = DoubRat(AlbertaTotalCasesList)
Pr6 = DoubRat(ManitobaTotalCasesList)
Pr7 = DoubRat(SaskatchewanTotalCasesList)
Pr8 = DoubRat(NewBrunswickTotalCasesList)
Pr9 = DoubRat(NewfoundlandAndLabradorTotalCasesList)
Pr10 = DoubRat(NovaScotiaTotalCasesList)
Pr11 = DoubRat(PrinceEdwardIslandTotalCasesList)

Pr13 = DoubRat(YukonTotalCasesList)
Pr14 = DoubRat(RepatriatedTravellersTotalCasesList)


#Plottting data for prediction of total cases
Results = ['Ontario', 'BritishColumbia', 'Canada', 'Quebec', 'Alberta', 'Manitoba', 'Saskatchewan', 'NewBrunswick', 'Newfoundland', 'NovaScotia', 'PrinceEdward', 'Yukon', 'Repatriated']
Days = [Pr1, Pr2, Pr3, Pr4, Pr5, Pr6, Pr7, Pr8, Pr9, Pr10, Pr11, Pr13, Pr14]
plt.bar(Results, Days)
plt.xticks(Results, Results, rotation='vertical')
plt.ylabel('Doubling rate for Total Cases ')
plt.title('Doubling rate plot')
plt.gcf().subplots_adjust(bottom=0.30)
plt.savefig('DoublingRateTotalCases.png')
plt.show()


#Pulling data from DoubRate function by passing total deaths list of each province as argument
Pr1 = DoubRat(OntarioTotalDeaths)
Pr2 = DoubRat(BritishColumbiaTotalDeaths)
Pr3 = DoubRat(CanadaTotalDeaths)
Pr4 = DoubRat(QuebecTotalDeaths)
Pr5 = DoubRat(AlbertaTotalDeaths)
Pr6 = DoubRat(ManitobaTotalDeaths)
Pr7 = DoubRat(SaskatchewanTotalDeaths)
Pr8 = DoubRat(NewBrunswickTotalDeaths)
Pr9 = DoubRat(NewfoundlandAndLabradorTotalDeaths)
Pr10 = DoubRat(NovaScotiaTotalDeaths)
Pr11 = DoubRat(PrinceEdwardIslandTotalDeaths)
Pr12 = DoubRat(NunavutTotalDeaths)
Pr13 = DoubRat(YukonTotalDeaths)
Pr14 = DoubRat(RepatriatedTravellersTotalDeaths)


#Plottting data for prediction of total deaths
Results = ['Ontario', 'BritishColumbia', 'Canada', 'Quebec', 'Alberta', 'Manitoba', 'Saskatchewan', 'NewBrunswick', 'Newfoundland', 'NovaScotia', 'PrinceEdward', 'Nunavut', 'Yukon', 'Repatriated']
Days = [Pr1, Pr2, Pr3, Pr4, Pr5, Pr6, Pr7, Pr8, Pr9, Pr10, Pr11, Pr12, Pr13, Pr14]
plt.bar(Results, Days)
plt.xticks(Results, Results, rotation='vertical')
plt.ylabel('Doubling rate for Total Deaths')
plt.title('Doubling rate plot')
plt.gcf().subplots_adjust(bottom=0.30)
plt.savefig('DoublingRateTotalDeaths.png')
plt.show()




#Pulling data from DoubRate function by passing New Cases list of each province as argument
Pr1 = DoubRat(OntarioNewCasesPerDay)
Pr2 = DoubRat(BritishColumbiaNewCasesPerDay)
Pr3 = DoubRat(CanadaNewCasesPerDay)
Pr4 = DoubRat(QuebecNewCasesPerDay)
Pr5 = DoubRat(AlbertaNewCasesPerDay)
Pr6 = DoubRat(ManitobaNewCasesPerDay)
Pr7 = DoubRat(SaskatchewanNewCasesPerDay)
Pr8 = DoubRat(NewBrunswickNewCasesPerDay)
Pr9 = DoubRat(NewfoundlandAndLabradorNewCasesPerDay)
Pr10 = DoubRat(NovaScotiaNewCasesPerDay)
Pr11 = DoubRat(PrinceEdwardIslandNewCasesPerDay)
Pr12 = DoubRat(NunavutNewCasesPerDay)
Pr13 = DoubRat(YukonNewCasesPerDay)
Pr14 = DoubRat(RepatriatedTravellersNewCasesPerDay)


Results = ['Ontario', 'BritishColumbia', 'Canada', 'Quebec', 'Alberta', 'Manitoba', 'Saskatchewan', 'NewBrunswick', 'Newfoundland', 'NovaScotia', 'PrinceEdward', 'Nunavut', 'Yukon', 'Repatriated']
Days = [Pr1, Pr2, Pr3, Pr4, Pr5, Pr6, Pr7, Pr8, Pr9, Pr10, Pr11, Pr12, Pr13, Pr14]
plt.bar(Results, Days)
plt.xticks(Results, Results, rotation='vertical')
plt.ylabel('Doubling rate for New Cases ')
plt.title('Doubling rate plot')
plt.gcf().subplots_adjust(bottom=0.30)
plt.savefig('DoublingRateNewCases.png')
plt.show()


#Project specific data and plots
res = ['Total Cases', 'Total tested', 'New Cases', 'Total Death']

if ProvinceName == 'Ontario':
    doub = [DoubRat(OntarioTotalCasesList), DoubRat(OntarioTotalTested), DoubRat(OntarioNewCasesPerDay), DoubRat(OntarioTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Ontario')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(OntarioTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(OntarioTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(OntarioNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(OntarioTotalDeaths)) + '\n')
    f.close()

if ProvinceName == 'Britishcolumbia':
    doub = [DoubRat(BritishColumbiaTotalCasesList), DoubRat(BritishColumbiaTotalTested), DoubRat(BritishColumbiaNewCasesPerDay), DoubRat(BritishColumbiaTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Britishcolumbia')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(BritishColumbiaTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(BritishColumbiaTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(BritishColumbiaNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(BritishColumbiaTotalDeaths)) + '\n')
    f.close()

if ProvinceName == 'Canada':
    doub = [DoubRat(CanadaTotalCasesList), DoubRat(CanadaTotalTested), DoubRat(CanadaNewCasesPerDay), DoubRat(CanadaTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Canada')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(CanadaTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(CanadaTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(CanadaNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(CanadaTotalDeaths)) + '\n')
    f.close()

if ProvinceName == 'Quebec':
    doub = [DoubRat(QuebecTotalCasesList), DoubRat(QuebecTotalTested), DoubRat(QuebecNewCasesPerDay), DoubRat(QuebecTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Quebec')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(QuebecTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(QuebecTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(QuebecNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(QuebecTotalDeaths)) + '\n')
    f.close()

if ProvinceName == 'Alberta':
    doub = [DoubRat(AlbertaTotalCasesList), DoubRat(AlbertaTotalTested), DoubRat(AlbertaNewCasesPerDay), DoubRat(AlbertaTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Alberta')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(AlbertaTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(AlbertaTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(AlbertaNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(AlbertaTotalDeaths)) + '\n')
    f.close()

if ProvinceName == 'Manitoba':
    doub = [DoubRat(ManitobaTotalCasesList), DoubRat(ManitobaTotalTested), DoubRat(ManitobaNewCasesPerDay), DoubRat(ManitobaTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Manotoba')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(ManitobaTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(ManitobaTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(ManitobaNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(ManitobaTotalDeaths)) + '\n')
    f.close()

if ProvinceName == 'Saskatchewan':
    doub = [DoubRat(SaskatchewanTotalCasesList), DoubRat(SaskatchewanTotalTested), DoubRat(SaskatchewanNewCasesPerDay), DoubRat(SaskatchewanTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Saskatchewan')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(SaskatchewanTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(SaskatchewanTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(SaskatchewanNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(SaskatchewanTotalDeaths)) + '\n')
    f.close()


if ProvinceName == 'Newbrunswick':
    doub = [DoubRat(NewBrunswickTotalCasesList), DoubRat(NewBrunswickTotalTested), DoubRat(NewBrunswickNewCasesPerDay), DoubRat(NewBrunswickTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Newbrunswick')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(NewBrunswickTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(NewBrunswickTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(NewBrunswickNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(NewBrunswickTotalDeaths)) + '\n')
    f.close()

if ProvinceName == 'Newfoundland':
    doub = [DoubRat(NewfoundlandAndLabradorTotalCasesList), DoubRat(NewfoundlandAndLabradorTotalTested), DoubRat(NewfoundlandAndLabradorNewCasesPerDay), DoubRat(NewfoundlandAndLabradorTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Newfoundland')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(NewfoundlandAndLabradorTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(NewfoundlandAndLabradorTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(NewfoundlandAndLabradorNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(NewfoundlandAndLabradorTotalDeaths)) + '\n')
    f.close()

if ProvinceName == 'Novascotia':
    doub = [DoubRat(NovaScotiaTotalCasesList), DoubRat(NovaScotiaTotalTested), DoubRat(NovaScotiaNewCasesPerDay), DoubRat(NovaScotiaTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Novascotia')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(NovaScotiaTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(NovaScotiaTotalTested)) + '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(NovaScotiaNewCasesPerDay)) + '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(NovaScotiaTotalDeaths)) + '\n')
    f.close()


if ProvinceName == 'Princeedwardisland':
    doub = [DoubRat(PrinceEdwardIslandTotalCasesList), DoubRat(PrinceEdwardIslandTotalTested), DoubRat(PrinceEdwardIslandNewCasesPerDay), DoubRat(PrinceEdwardIslandTotalDeaths)]
    plt.bar(res, doub)
    plt.xticks(res, res, rotation='vertical')
    plt.ylabel('Number of days')
    plt.title('Doubling rate plot for Princeedwardisland')
    plt.show()
    f = open("DoublingRateData.txt", "a")
    f.write('Doubling rate data for the province ' + ProvinceName + '\n\n')
    f.write('Number of days it may take for the Total cases to double is ' + str(DoubRat(PrinceEdwardIslandTotalCasesList)) + '\n')
    f.write('Number of days it may take for the Total Tests to double is ' + str(DoubRat(PrinceEdwardIslandTotalTested))+ '\n')
    f.write('Number of days it may take for the New cases to double is ' + str(DoubRat(PrinceEdwardIslandNewCasesPerDay))+ '\n')
    f.write('Number of days it may take for the Total Deaths to double is ' + str(DoubRat(PrinceEdwardIslandTotalDeaths))+ '\n')
    f.close()
